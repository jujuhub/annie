# %%
import pandas as pd
import torch
import numpy as np
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Define ManyToOneRNN class

# %%
class ManyToOneRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(ManyToOneRNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True,nonlinearity='relu')
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        # Initialize hidden state with zeros
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        # Forward propagate the RNN
        out, _ = self.rnn(x,h0)

        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ## Define MyDataset Class (not needed)

# %%
class MyDataset(Dataset):
    def __init__(self, dataframe):
        self.data = dataframe

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        evid = self.data.iloc[idx,0]    #added to include evid in output file
        features = torch.tensor(self.data.iloc[idx, 1:-1], dtype=torch.float32)
        features = features.t()
        target = torch.tensor(self.data.iloc[idx, -1], dtype=torch.float32)
        return evid, features, target   #added evid as return value

# %% [markdown]
# ## Load model

# %%
model = torch.load('/Users/juhe/annie/analysis/Muon_vertex/model.pth')
model.eval()
# Out:
# ManyToOneRNN(
#   (rnn): RNN(2, 4, batch_first=True)
#   (fc): Linear(in_features=4, out_features=1, bias=True)
# )

# %% [markdown]
# ## Load data (needs to be in Tensor format)

# %%
# h5 format
data = pd.read_hdf('/Users/juhe/annie/analysis/Muon_vertex/data.h5', 'df')
data.head(5)
# Out:
#         id                                                 ai  \
# 0    p0_66  [70, 100, 115, 130, 145, 160, 175, 190, 205, 2...
# 1  p100_11  [70, 100, 115, 130, 145, 175, 205, 220, 235, 2...
# 2  p102_48  [70, 100, 115, 130, 145, 160, 175, 190, 205, 2...
# 3  p104_61  [70, 100, 115, 130, 145, 160, 175, 190, 205, 2...
# 4  p104_97  [55, 70, 85, 100, 115, 130, 160, 175, 190, 205...
#
#                                                  eta  truetracklen
# 0  [1847.96, 1125.22, 1636.88, 1500.98, 2160.9, 1...       147.972
# 1  [3902.38, 1059.4, 3823.62, 1585.48, 3049.67, 1...       188.655
# 2  [921.235, 1818.78, 1769.22, 1853.33, 2079.88, ...       176.992
# 3  [2840.03, 1991.47, 2949.01, 1859.28, 2389.12, ...       303.262
# 4  [2915.57, 2026.21, 1047.48, 109.152, 93.3911, ...       125.716

# %%
#data.iloc[2,1:-1]   # the first number selects just the 2nd row; the second number selects the columns
data.iloc[:,1:]   # prints all rows
# Out:
#                                                      ai  \
# 0     [70, 100, 115, 130, 145, 160, 175, 190, 205, 2...
# 1     [70, 100, 115, 130, 145, 175, 205, 220, 235, 2...
# 2     [70, 100, 115, 130, 145, 160, 175, 190, 205, 2...
# 3     [70, 100, 115, 130, 145, 160, 175, 190, 205, 2...
# 4     [55, 70, 85, 100, 115, 130, 160, 175, 190, 205...
# ...                                                 ...
# 1203  [70, 85, 100, 115, 130, 145, 175, 190, 205, 22...
# 1204  [55, 70, 85, 100, 115, 130, 145, 160, 175, 190...
# 1205  [55, 70, 85, 100, 115, 130, 145, 160, 175, 190...
# 1206  [55, 85, 100, 115, 145, 160, 175, 190, 205, 22...
# 1207  [70, 85, 115, 130, 145, 160, 175, 205, 220, 23...
#
#                                                     eta
# 0     [1847.96, 1125.22, 1636.88, 1500.98, 2160.9, 1...
# 1     [3902.38, 1059.4, 3823.62, 1585.48, 3049.67, 1...
# 2     [921.235, 1818.78, 1769.22, 1853.33, 2079.88, ...
# 3     [2840.03, 1991.47, 2949.01, 1859.28, 2389.12, ...
# 4     [2915.57, 2026.21, 1047.48, 109.152, 93.3911, ...
# ...                                                 ...
# 1203  [3255.71, 2179.67, 1000.26, 3099.8, 1554.33, 3...
# 1204  [7974.39, 3223.17, 8453.17, 5943.81, 3536.89, ...
# 1205  [5206.06, 2499.49, 1726.9, 2406.31, 2801.53, 3...
# 1206  [4837.46, 3448.8, 2344.75, 2591.72, 1900.58, 1...
# 1207  [120.905, 603.856, 356.003, 233.975, 323.261, ...
#
# [1208 rows x 2 columns]

# %%
# drop truth col
data = data.drop(columns=['truetracklen'])
data.head(5)
# Out:
#         id                                                 ai  \
# 0    p0_66  [70, 100, 115, 130, 145, 160, 175, 190, 205, 2...
# 1  p100_11  [70, 100, 115, 130, 145, 175, 205, 220, 235, 2...
# 2  p102_48  [70, 100, 115, 130, 145, 160, 175, 190, 205, 2...
# 3  p104_61  [70, 100, 115, 130, 145, 160, 175, 190, 205, 2...
# 4  p104_97  [55, 70, 85, 100, 115, 130, 160, 175, 190, 205...
#
#                                                  eta
# 0  [1847.96, 1125.22, 1636.88, 1500.98, 2160.9, 1...
# 1  [3902.38, 1059.4, 3823.62, 1585.48, 3049.67, 1...
# 2  [921.235, 1818.78, 1769.22, 1853.33, 2079.88, ...
# 3  [2840.03, 1991.47, 2949.01, 1859.28, 2389.12, ...
# 4  [2915.57, 2026.21, 1047.48, 109.152, 93.3911, ...

# %%
# not needed
# dataS = MyDataset(data)
# dataloader = DataLoader(dataS)

# convert data into tensor
dataT = torch.tensor(data.iloc[:,1:].values).t()   # this line with .values doesn't work
dataT.unsqueeze_(0)
print(dataT.size())
print(dataT)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-cfb2b8612715> in <module>
#       4
#       5 # convert data into tensor
# ----> 6 dataT = torch.tensor(data.iloc[:,1:].values).t()
#       7 dataT.unsqueeze_(0)
#       8 print(dataT.size())
#
# TypeError: can't convert np.ndarray of type numpy.object_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint8, and bool.

# %%
data_r2633 = pd.read_csv('/Users/juhe/annie/analysis/ev_ai_eta_r2633.txt', header=None, names=['evid','ai','eta'])
data_r2633.head(5)
# Out:
#      evid   ai       eta
# 0  p1_884   70  2230.380
# 1  p1_884   85  2646.420
# 2  p1_884  115   882.544
# 3  p1_884  130  1309.770
# 4  p1_884  145  3528.670

# %%
data_r2633 = data_r2633.groupby('evid').agg(list).reset_index()
data_r2633.head(5)
# Out:
#         evid                                                 ai  \
# 0  p104_1374  [70, 85, 115, 130, 145, 160, 175, 190, 205, 22...
# 1  p105_3956  [70, 85, 100, 130, 145, 160, 175, 190, 205, 22...
# 2  p106_2078                                         [355, 370]
# 3  p106_2267  [70, 85, 115, 130, 145, 160, 190, 205, 220, 23...
# 4  p118_1648                                    [100, 115, 130]
#
#                                                  eta
# 0  [1340.04, 1005.23, 1941.67, 2167.4, 1567.54, 2...
# 1  [1494.16, 1346.65, 1878.08, 1374.96, 2435.83, ...
# 2                                  [91.1868, 149.54]
# 3  [3378.22, 975.051, 2383.83, 2210.3, 3012.36, 2...
# 4                        [28.5719, 115.743, 64.9081]

# %%
# open file to write to
out_f = open("fitbyeye_r2633_RNN.txt", "a")

for idx in range(len(data_r2633)):
    dataT = torch.tensor(data_r2633.iloc[idx,1:]).t()
    dataT.unsqueeze_(0)
    out = model(dataT)
    print(data_r2633.iloc[idx,0], out)
    out_f.write(str(data_r2633.iloc[idx,0]) + "," + str(out.data.numpy()[0][0]) + "\n")
# Out:
# p104_1374 tensor([[196.0140]], grad_fn=<AddmmBackward0>)
# p105_3956 tensor([[185.3026]], grad_fn=<AddmmBackward0>)
# p106_2078 tensor([[37.6015]], grad_fn=<AddmmBackward0>)
# p106_2267 tensor([[244.0697]], grad_fn=<AddmmBackward0>)
# p118_1648 tensor([[26.6526]], grad_fn=<AddmmBackward0>)
# p118_1876 tensor([[56.9690]], grad_fn=<AddmmBackward0>)
# p11_513 tensor([[235.3429]], grad_fn=<AddmmBackward0>)
# p120_3869 tensor([[105.4688]], grad_fn=<AddmmBackward0>)
# p121_735 tensor([[268.9644]], grad_fn=<AddmmBackward0>)
# p123_1101 tensor([[154.5600]], grad_fn=<AddmmBackward0>)
# p123_3892 tensor([[162.4580]], grad_fn=<AddmmBackward0>)
# p124_2066 tensor([[113.1103]], grad_fn=<AddmmBackward0>)
# p127_298 tensor([[98.2866]], grad_fn=<AddmmBackward0>)
# p128_1711 tensor([[219.7200]], grad_fn=<AddmmBackward0>)
# p128_2764 tensor([[151.7610]], grad_fn=<AddmmBackward0>)
# p129_3029 tensor([[191.5911]], grad_fn=<AddmmBackward0>)
# p135_3460 tensor([[205.4232]], grad_fn=<AddmmBackward0>)
# p140_185 tensor([[136.7501]], grad_fn=<AddmmBackward0>)
# p141_2686 tensor([[98.4689]], grad_fn=<AddmmBackward0>)
# p142_1598 tensor([[119.6987]], grad_fn=<AddmmBackward0>)
# p143_1561 tensor([[-19.5761]], grad_fn=<AddmmBackward0>)
# p145_2242 tensor([[150.7404]], grad_fn=<AddmmBackward0>)
# p146_3339 tensor([[105.7665]], grad_fn=<AddmmBackward0>)
# p148_486 tensor([[161.2572]], grad_fn=<AddmmBackward0>)
# p154_412 tensor([[149.2963]], grad_fn=<AddmmBackward0>)
# p155_4693 tensor([[185.8482]], grad_fn=<AddmmBackward0>)
# p15_2547 tensor([[117.3090]], grad_fn=<AddmmBackward0>)
# p15_3229 tensor([[155.6368]], grad_fn=<AddmmBackward0>)
# p164_3606 tensor([[92.7552]], grad_fn=<AddmmBackward0>)
# p165_1822 tensor([[131.9123]], grad_fn=<AddmmBackward0>)
# p165_795 tensor([[140.5892]], grad_fn=<AddmmBackward0>)
# p169_2322 tensor([[101.7038]], grad_fn=<AddmmBackward0>)
# p178_2495 tensor([[145.3106]], grad_fn=<AddmmBackward0>)
# p182_3134 tensor([[214.4081]], grad_fn=<AddmmBackward0>)
# p186_4646 tensor([[156.9001]], grad_fn=<AddmmBackward0>)
# p186_98 tensor([[236.1572]], grad_fn=<AddmmBackward0>)
# p189_1797 tensor([[118.0132]], grad_fn=<AddmmBackward0>)
# p190_2998 tensor([[92.6647]], grad_fn=<AddmmBackward0>)
# p1_884 tensor([[170.7334]], grad_fn=<AddmmBackward0>)
# p203_1062 tensor([[72.5291]], grad_fn=<AddmmBackward0>)
# p204_2528 tensor([[156.2017]], grad_fn=<AddmmBackward0>)
# p205_1642 tensor([[252.7004]], grad_fn=<AddmmBackward0>)
# p206_2346 tensor([[46.0773]], grad_fn=<AddmmBackward0>)
# p208_2259 tensor([[259.3673]], grad_fn=<AddmmBackward0>)
# p209_1105 tensor([[86.0821]], grad_fn=<AddmmBackward0>)
# p20_2940 tensor([[119.1605]], grad_fn=<AddmmBackward0>)
# p210_3595 tensor([[106.5081]], grad_fn=<AddmmBackward0>)
# p217_2986 tensor([[257.0746]], grad_fn=<AddmmBackward0>)
# p21_49 tensor([[277.2621]], grad_fn=<AddmmBackward0>)
# p221_3779 tensor([[243.5072]], grad_fn=<AddmmBackward0>)
# p238_2180 tensor([[283.4237]], grad_fn=<AddmmBackward0>)
# p238_2863 tensor([[242.6256]], grad_fn=<AddmmBackward0>)
# p244_1424 tensor([[224.2986]], grad_fn=<AddmmBackward0>)
# p248_4384 tensor([[124.4960]], grad_fn=<AddmmBackward0>)
# p250_3265 tensor([[103.3331]], grad_fn=<AddmmBackward0>)
# p255_35 tensor([[249.4508]], grad_fn=<AddmmBackward0>)
# p255_891 tensor([[239.4107]], grad_fn=<AddmmBackward0>)
# p264_2550 tensor([[221.2112]], grad_fn=<AddmmBackward0>)
# p268_890 tensor([[173.0831]], grad_fn=<AddmmBackward0>)
# p269_4044 tensor([[161.5790]], grad_fn=<AddmmBackward0>)
# p272_4098 tensor([[246.8094]], grad_fn=<AddmmBackward0>)
# p273_1531 tensor([[144.8689]], grad_fn=<AddmmBackward0>)
# p273_3588 tensor([[100.2939]], grad_fn=<AddmmBackward0>)
# p274_699 tensor([[88.4616]], grad_fn=<AddmmBackward0>)
# p275_3724 tensor([[145.2813]], grad_fn=<AddmmBackward0>)
# p279_1292 tensor([[95.3332]], grad_fn=<AddmmBackward0>)
# p279_3199 tensor([[-53.9519]], grad_fn=<AddmmBackward0>)
# p27_3080 tensor([[175.1468]], grad_fn=<AddmmBackward0>)
# p280_1859 tensor([[202.9889]], grad_fn=<AddmmBackward0>)
# p281_2771 tensor([[141.5032]], grad_fn=<AddmmBackward0>)
# p281_2919 tensor([[264.8569]], grad_fn=<AddmmBackward0>)
# p284_2851 tensor([[109.3532]], grad_fn=<AddmmBackward0>)
# p284_3642 tensor([[270.4486]], grad_fn=<AddmmBackward0>)
# p284_3682 tensor([[116.4617]], grad_fn=<AddmmBackward0>)
# p284_3752 tensor([[158.4083]], grad_fn=<AddmmBackward0>)
# p284_3995 tensor([[38.6208]], grad_fn=<AddmmBackward0>)
# p285_3397 tensor([[156.2395]], grad_fn=<AddmmBackward0>)
# p287_650 tensor([[102.2398]], grad_fn=<AddmmBackward0>)
# p28_107 tensor([[154.9821]], grad_fn=<AddmmBackward0>)
# p290_331 tensor([[228.7496]], grad_fn=<AddmmBackward0>)
# p298_1224 tensor([[116.2410]], grad_fn=<AddmmBackward0>)
# p29_1517 tensor([[228.5034]], grad_fn=<AddmmBackward0>)
# p2_1639 tensor([[229.4473]], grad_fn=<AddmmBackward0>)
# p2_3661 tensor([[109.4809]], grad_fn=<AddmmBackward0>)
# p300_1359 tensor([[141.0721]], grad_fn=<AddmmBackward0>)
# p300_308 tensor([[216.7567]], grad_fn=<AddmmBackward0>)
# p304_1930 tensor([[170.2592]], grad_fn=<AddmmBackward0>)
# p304_3088 tensor([[175.5976]], grad_fn=<AddmmBackward0>)
# p306_1189 tensor([[165.7709]], grad_fn=<AddmmBackward0>)
# p306_1978 tensor([[255.3821]], grad_fn=<AddmmBackward0>)
# p306_563 tensor([[126.8468]], grad_fn=<AddmmBackward0>)
# p30_317 tensor([[294.4594]], grad_fn=<AddmmBackward0>)
# p311_2086 tensor([[94.4296]], grad_fn=<AddmmBackward0>)
# p314_1298 tensor([[213.4228]], grad_fn=<AddmmBackward0>)
# p315_2841 tensor([[275.5432]], grad_fn=<AddmmBackward0>)
# p315_3307 tensor([[75.6899]], grad_fn=<AddmmBackward0>)
# p316_2935 tensor([[134.4233]], grad_fn=<AddmmBackward0>)
# p316_3124 tensor([[87.6939]], grad_fn=<AddmmBackward0>)
# p317_1491 tensor([[176.7951]], grad_fn=<AddmmBackward0>)
# p317_2167 tensor([[167.5851]], grad_fn=<AddmmBackward0>)
# p317_2364 tensor([[117.4755]], grad_fn=<AddmmBackward0>)
# p31_2597 tensor([[99.3799]], grad_fn=<AddmmBackward0>)
# p321_3604 tensor([[166.4440]], grad_fn=<AddmmBackward0>)
# p323_4290 tensor([[135.6079]], grad_fn=<AddmmBackward0>)
# p323_573 tensor([[97.9106]], grad_fn=<AddmmBackward0>)
# p324_1160 tensor([[246.1238]], grad_fn=<AddmmBackward0>)
# p326_2573 tensor([[66.5649]], grad_fn=<AddmmBackward0>)
# p327_2891 tensor([[65.6356]], grad_fn=<AddmmBackward0>)
# p327_3548 tensor([[170.7845]], grad_fn=<AddmmBackward0>)
# p330_3838 tensor([[113.3208]], grad_fn=<AddmmBackward0>)
# p332_3503 tensor([[40.5125]], grad_fn=<AddmmBackward0>)
# p334_1511 tensor([[110.4112]], grad_fn=<AddmmBackward0>)
# p334_1515 tensor([[231.0933]], grad_fn=<AddmmBackward0>)
# p334_1800 tensor([[106.5821]], grad_fn=<AddmmBackward0>)
# p335_1380 tensor([[44.8495]], grad_fn=<AddmmBackward0>)
# p335_3176 tensor([[65.8547]], grad_fn=<AddmmBackward0>)
# p335_4007 tensor([[86.5797]], grad_fn=<AddmmBackward0>)
# p336_1618 tensor([[54.4974]], grad_fn=<AddmmBackward0>)
# p336_310 tensor([[189.2110]], grad_fn=<AddmmBackward0>)
# p338_145 tensor([[191.1927]], grad_fn=<AddmmBackward0>)
# p338_1470 tensor([[148.8963]], grad_fn=<AddmmBackward0>)
# p338_4741 tensor([[134.1953]], grad_fn=<AddmmBackward0>)
# p339_1814 tensor([[94.9557]], grad_fn=<AddmmBackward0>)
# p339_4638 tensor([[143.5231]], grad_fn=<AddmmBackward0>)
# p339_4977 tensor([[135.3519]], grad_fn=<AddmmBackward0>)
# p340_2704 tensor([[256.8352]], grad_fn=<AddmmBackward0>)
# p341_113 tensor([[154.6372]], grad_fn=<AddmmBackward0>)
# p37_3974 tensor([[116.6147]], grad_fn=<AddmmBackward0>)
# p38_681 tensor([[106.5946]], grad_fn=<AddmmBackward0>)
# p40_574 tensor([[118.5135]], grad_fn=<AddmmBackward0>)
# p41_2423 tensor([[217.1536]], grad_fn=<AddmmBackward0>)
# p43_1480 tensor([[198.4299]], grad_fn=<AddmmBackward0>)
# p46_3857 tensor([[150.3421]], grad_fn=<AddmmBackward0>)
# p47_1054 tensor([[92.0333]], grad_fn=<AddmmBackward0>)
# p47_351 tensor([[108.9744]], grad_fn=<AddmmBackward0>)
# p48_1935 tensor([[77.0644]], grad_fn=<AddmmBackward0>)
# p51_1554 tensor([[208.5841]], grad_fn=<AddmmBackward0>)
# p54_4727 tensor([[217.1617]], grad_fn=<AddmmBackward0>)
# p56_3197 tensor([[157.6561]], grad_fn=<AddmmBackward0>)
# p56_3445 tensor([[173.0455]], grad_fn=<AddmmBackward0>)
# p60_189 tensor([[245.7407]], grad_fn=<AddmmBackward0>)
# p63_2565 tensor([[250.1794]], grad_fn=<AddmmBackward0>)
# p63_2871 tensor([[170.5093]], grad_fn=<AddmmBackward0>)
# p70_3327 tensor([[192.1540]], grad_fn=<AddmmBackward0>)
# p71_2830 tensor([[127.4203]], grad_fn=<AddmmBackward0>)
# p73_3446 tensor([[65.1883]], grad_fn=<AddmmBackward0>)
# p73_879 tensor([[136.3611]], grad_fn=<AddmmBackward0>)
# p76_2983 tensor([[157.2441]], grad_fn=<AddmmBackward0>)
# p78_2016 tensor([[167.6750]], grad_fn=<AddmmBackward0>)
# p7_1197 tensor([[153.7053]], grad_fn=<AddmmBackward0>)
# p80_1017 tensor([[253.7676]], grad_fn=<AddmmBackward0>)
# p80_2736 tensor([[91.5050]], grad_fn=<AddmmBackward0>)
# p81_2751 tensor([[227.0088]], grad_fn=<AddmmBackward0>)
# p82_1519 tensor([[235.8958]], grad_fn=<AddmmBackward0>)
# p82_2189 tensor([[73.9416]], grad_fn=<AddmmBackward0>)
# p82_689 tensor([[130.3162]], grad_fn=<AddmmBackward0>)
# p83_3364 tensor([[-30.3370]], grad_fn=<AddmmBackward0>)
# p84_2874 tensor([[93.1781]], grad_fn=<AddmmBackward0>)
# p85_4055 tensor([[195.6964]], grad_fn=<AddmmBackward0>)
# p87_471 tensor([[152.5490]], grad_fn=<AddmmBackward0>)
# p91_2450 tensor([[188.8239]], grad_fn=<AddmmBackward0>)
# p97_151 tensor([[89.2594]], grad_fn=<AddmmBackward0>)
# p97_2964 tensor([[138.5030]], grad_fn=<AddmmBackward0>)

# %%
out_f.close()

# %%
model(dataT)
# Out:
# torch.Size([1, 1])

# %%
# using MyDataset and DataLoader
for evid, data, target in dataloader:
    out = model(data)
    print(evid,out)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-89674956eedd> in <module>
# ----> 1 for evid, data, target in dataloader:
#       2     out = model(data)
#       3     print(evid,out)
#
# /usr/local/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# <ipython-input-19-f0169a0dfc20> in __getitem__(self, idx)
#       7
#       8     def __getitem__(self, idx):
# ----> 9         evid = self.data.iloc[idx,0]    #added to include evid in output file
#      10         features = torch.tensor(self.data.iloc[idx, 1:-1], dtype=torch.float32)
#      11         features = features.t()
#
# AttributeError: 'Tensor' object has no attribute 'iloc'
